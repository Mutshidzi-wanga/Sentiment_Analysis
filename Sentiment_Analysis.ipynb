# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
import pandas as pd

df = pd.read_csv('/content/sentiment_reviews.csv')

df.head()
# Out:
#    ID                                             Review Sentiment
# 0   1  I absolutely love this product! It exceeded my...  positive
# 1   2  This was the worst experience I've had with an...  negative
# 2   3      Not bad, but could be improved in some areas.   neutral
# 3   4  The delivery was quick and the packaging was e...  positive
# 4   5       I wouldn’t recommend this to my worst enemy.  negative

# %%
df.info()
df['Sentiment'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         20 non-null     int64
#  1   Review     20 non-null     object
#  2   Sentiment  20 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 612.0+ bytes
# Sentiment
# positive    8
# negative    6
# neutral     6
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Sentiment'].value_counts().plot.pie(autopct='%1.1f%%', colors=['green', 'red', 'gray'], startangle=90)
plt.title("Sentiment Distribution")
plt.ylabel("")
plt.show()

df['Sentiment'].value_counts().plot(kind='bar', color=['green', 'red', 'gray'])
plt.title("Review Sentiment Count")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
